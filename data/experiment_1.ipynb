# %% [markdown]
# <a id='exp_1'></a>

# %%
import ipywidgets as wid

# %% [markdown]
# ___

# %% [markdown]
# # Experiment #1

# %% [markdown]
# ___

# %% [markdown]
# ## Calibrations

# %%
 wid.FloatText(
    value=7.5,
    description='Any:',
    disabled=False,
    color='black'
)
# Out:
# FloatText(value=7.5, description='Any:')

# %% [markdown]
# ## Method #1
