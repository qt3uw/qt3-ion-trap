# %% [markdown]
# # Planar Trap Experimental Data Collection/Analysis

# %% [markdown]
# ___
# ___

# %% [markdown]
# ## Table of Contents
# ***

# %% [markdown]
# - #### [Experiment #1](experiment_1.ipynb#exp_1)
#   - #### Calibration
#   - #### Method #1
#   - #### Method #2

# %% [markdown]
# - #### [Experiment #2](experiment_2.ipynb#exp_2)
#     - #### Calibration

# %% [markdown]
# # Experiment
